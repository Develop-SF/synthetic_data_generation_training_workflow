# %% [markdown]
# #  Synthetic Data Generation and Training Workflow with Warehouse Sim Ready Assets
#
# This notebook is the second part of the SDG and Training Workflow. Here, we will be focusing on training an Object Detection Network with TAO toolkit
#
# A high level overview of the steps:
# * Pulling TAO Docker Container
# * Training Detectnet_v2 model with generated Synthetic Data
# * Visualizing Model Performance on Sample Real World Data
#
# `This notebook is very similar to the cloud training notebook, only mounted directories and paths for the docker containers are changed. The data, model and training, evaluation and inference steps are identical`

# %% [markdown]
# #### If Isaac Sim is installed locally, ensure that data generation is complete. Run the `generate_data.sh` script in this folder. Ensure the path to Isaac Sim is set correctly in the script (`ISAAC_SIM_PATH` corresponds to where Isaac Sim is installed locally on your workstation)

# %% [markdown]
# ### Table of Contents
#
# This notebook shows an example usecase of Object Detection using DetectNet_v2 in the Train Adapt Optimize (TAO) Toolkit. We will train the model with Synthetic Data generated previously.
#
# 1. [Set up TAO via Docker container](#head-1)
# 2. [Download Pretrained model](#head-2)
# 3. [Convert Dataset to TFRecords for TAO](#head-3)
# 4. [Provide training specification](#head-4)
# 5. [Run TAO training](#head-5)
# 6. [Evaluate trained model](#head-6)
# 7. [Visualize Model Predictions on Real World Data](#head-7)
# 8. [Next Steps](#head-8)

# %% [markdown]
# ## 1. Set up TAO via Docker Container <a class="anchor" id="head-1"></a>
#
# * We will follow the pre-requisites section of [instructions](https://docs.nvidia.com/tao/tao-toolkit/text/tao_toolkit_quick_start_guide.html#running-tao-toolkit) for using TAO toolkit. Make sure that the pre-requisite steps are completed (installing `docker`, `nvidia container toolkit` and `docker login nvcr.io`)
#
# * The docker container being used for training will be pulled in the cells below, make sure you have completed the pre-requisite steps and `docker login nvcr.io` to allow pulling of the container from NGC

# %%
import os
# %env DOCKER_REGISTRY=nvcr.io
# %env DOCKER_NAME=nvidia/tao/tao-toolkit
# %env DOCKER_TAG=4.0.0-tf1.15.5 ## for TensorFlow docker

# %env DOCKER_CONTAINER=nvcr.io/nvidia/tao/tao-toolkit:4.0.0-tf1.15.5
# Out:
# env: DOCKER_REGISTRY=nvcr.io
# env: DOCKER_NAME=nvidia/tao/tao-toolkit
# env: DOCKER_TAG=4.0.0-tf1.15.5 ## for TensorFlow docker
# env: DOCKER_CONTAINER=nvcr.io/nvidia/tao/tao-toolkit:4.0.0-tf1.15.5

# %% [markdown]
# ## 2. Download Pretrained Model <a class="anchor" id="head-2"></a>
#
# * We will use the `detectnet_v2` Object Detection model with a `resnet18` backbone
# * Make sure the `LOCAL_PROJECT_DIR` environment variable has the path of this cloned repository in the cell below

# %%
# os.environ["LOCAL_PROJECT_DIR"] = "<LOCAL_PATH_OF_CLONED_REPO>"
os.environ["LOCAL_PROJECT_DIR"] = os.path.dirname(os.getcwd()) # This is the location of the root of the cloned repo
print(os.environ["LOCAL_PROJECT_DIR"])
# Out:
# /home/shinfang-ovx/synthetic_data_generation_training_workflow

# %%
# !wget --quiet --show-progress --progress=bar:force:noscroll --auth-no-challenge --no-check-certificate \
        https://api.ngc.nvidia.com/v2/models/nvidia/tao/pretrained_detectnet_v2/versions/resnet18/files/resnet18.hdf5 \
        -P  $LOCAL_PROJECT_DIR/local/training/tao/pretrained_model/
# Out:
# resnet18.hdf5       100%[===================>]  89.02M  38.4MB/s    in 2.3s

# %% [markdown]
# ## 3. Convert Dataset to TFRecords for TAO <a class="anchor" id="head-3"></a>
#
# * The `Detectnet_v2` model in TAO expects data in the form of TFRecords for training.
# * We can convert the KITTI Format Dataset generated from Part 1 with the `detectnet_v2 dataset_convert` tool provided with TAO toolkit

# %%
print("Converting Tfrecords for kitchenware distractors dataset")

# !mkdir -p $LOCAL_PROJECT_DIR/local/training/tao/tfrecords/distractors_kitchen && rm -rf $LOCAL_PROJECT_DIR/local/training/tao/tfrecords/distractors_warehouse/*

# !docker run -it --rm --gpus all -v $LOCAL_PROJECT_DIR:/workspace/tao-experiments $DOCKER_CONTAINER \
                   detectnet_v2 dataset_convert \
                  -d /workspace/tao-experiments/local/training/tao/specs/tfrecords/distractors_kitchen.txt \
                  -o /workspace/tao-experiments/local/training/tao/tfrecords/distractors_kitchen/
# Out:
# Converting Tfrecords for kitchenware distractors dataset
#
# ==============================
# === TAO Toolkit TensorFlow ===
# ==============================
#
# NVIDIA Release 4.0.0-TensorFlow (build )
# TAO Toolkit Version 4.0.0
#
# Various files include modifications (c) NVIDIA CORPORATION & AFFILIATES.  All rights reserved.
#
# This container image and its contents are governed by the TAO Toolkit End User License Agreement.
# By pulling and using the container, you accept the terms and conditions of this license:
# https://developer.nvidia.com/tao-toolkit-software-license-agreement
#
# NOTE: The SHMEM allocation limit is set to the default of 64MB.  This may be
#    insufficient for TAO Toolkit.  NVIDIA recommends the use of the following flags:
#    docker run --gpus all --ipc=host --ulimit memlock=-1 --ulimit stack=67108864 ...
#
# Using TensorFlow backend.
# 2024-10-28 10:28:28.684320: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Using TensorFlow backend.
# 2024-10-28 10:28:32,367 [INFO] iva.detectnet_v2.dataio.build_converter: Instantiating a kitti converter
# 2024-10-28 10:28:32,368 [INFO] iva.detectnet_v2.dataio.kitti_converter_lib: Num images in
# Train: 360	Val: 40
# 2024-10-28 10:28:32,368 [INFO] iva.detectnet_v2.dataio.kitti_converter_lib: Validation data in partition 0. Hence, while choosing the validationset during training choose validation_fold 0.
# 2024-10-28 10:28:32,368 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 0
# 2024-10-28 10:28:32,372 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 1
# 2024-10-28 10:28:32,373 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 2
# 2024-10-28 10:28:32,374 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 3
# 2024-10-28 10:28:32,375 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 4
# 2024-10-28 10:28:32,376 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 5
# 2024-10-28 10:28:32,377 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 6
# 2024-10-28 10:28:32,379 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 7
# 2024-10-28 10:28:32,380 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 8
# 2024-10-28 10:28:32,381 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 9
# 2024-10-28 10:28:32,382 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib:
# Wrote the following numbers of objects:
# b'ladle': 120
# b'wok': 122
# b'bottle': 266
# b'tableware': 271
#
# 2024-10-28 10:28:32,382 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 0
# 2024-10-28 10:28:32,391 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 1
# 2024-10-28 10:28:32,399 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 2
# 2024-10-28 10:28:32,409 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 3
# 2024-10-28 10:28:32,418 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 4
# 2024-10-28 10:28:32,427 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 5
# 2024-10-28 10:28:32,435 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 6
# 2024-10-28 10:28:32,444 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 7
# 2024-10-28 10:28:32,453 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 8
# 2024-10-28 10:28:32,463 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 9
# 2024-10-28 10:28:32,473 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib:
# Wrote the following numbers of objects:
# b'bottle': 2457
# b'wok': 1192
# b'tableware': 2298
# b'ladle': 1092
#
# 2024-10-28 10:28:32,474 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Cumulative object statistics
# 2024-10-28 10:28:32,474 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib:
# Wrote the following numbers of objects:
# b'ladle': 1212
# b'wok': 1314
# b'bottle': 2723
# b'tableware': 2569
#
# 2024-10-28 10:28:32,474 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Class map.
# Label in GT: Label in tfrecords file
# b'ladle': b'ladle'
# b'wok': b'wok'
# b'bottle': b'bottle'
# b'tableware': b'tableware'
# For the dataset_config in the experiment_spec, please use labels in the tfrecords file, while writing the classmap.
#
# 2024-10-28 10:28:32,474 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Tfrecords generation complete.
# 2024-10-28 10:28:32,474 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing the log_warning.json
# 2024-10-28 10:28:32,474 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: There were errors in the labels. Details are logged at /workspace/tao-experiments/local/training/tao/tfrecords/distractors_kitchen/_waring.json
# Execution status: PASS

# %%
print("Converting Tfrecords for kitchenware with additional distractors")

# !mkdir -p $LOCAL_PROJECT_DIR/local/training/tao/tfrecords/distractors_additional && rm -rf $LOCAL_PROJECT_DIR/local/training/tao/tfrecords/distractors_additional/*

# !docker run -it --rm --gpus all -v $LOCAL_PROJECT_DIR:/workspace/tao-experiments $DOCKER_CONTAINER \
                   detectnet_v2 dataset_convert \
                  -d /workspace/tao-experiments/local/training/tao/specs/tfrecords/distractors_additional.txt \
                  -o /workspace/tao-experiments/local/training/tao/tfrecords/distractors_additional/
# Out:
# Converting Tfrecords for kitchenware with additional distractors
#
# ==============================
# === TAO Toolkit TensorFlow ===
# ==============================
#
# NVIDIA Release 4.0.0-TensorFlow (build )
# TAO Toolkit Version 4.0.0
#
# Various files include modifications (c) NVIDIA CORPORATION & AFFILIATES.  All rights reserved.
#
# This container image and its contents are governed by the TAO Toolkit End User License Agreement.
# By pulling and using the container, you accept the terms and conditions of this license:
# https://developer.nvidia.com/tao-toolkit-software-license-agreement
#
# NOTE: The SHMEM allocation limit is set to the default of 64MB.  This may be
#    insufficient for TAO Toolkit.  NVIDIA recommends the use of the following flags:
#    docker run --gpus all --ipc=host --ulimit memlock=-1 --ulimit stack=67108864 ...
#
# Using TensorFlow backend.
# 2024-10-28 10:28:36.576281: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Using TensorFlow backend.
# 2024-10-28 10:28:40,193 [INFO] iva.detectnet_v2.dataio.build_converter: Instantiating a kitti converter
# 2024-10-28 10:28:40,194 [INFO] iva.detectnet_v2.dataio.kitti_converter_lib: Num images in
# Train: 720	Val: 80
# 2024-10-28 10:28:40,194 [INFO] iva.detectnet_v2.dataio.kitti_converter_lib: Validation data in partition 0. Hence, while choosing the validationset during training choose validation_fold 0.
# 2024-10-28 10:28:40,194 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 0
# 2024-10-28 10:28:40,198 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 1
# 2024-10-28 10:28:40,200 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 2
# 2024-10-28 10:28:40,202 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 3
# 2024-10-28 10:28:40,204 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 4
# 2024-10-28 10:28:40,206 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 5
# 2024-10-28 10:28:40,208 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 6
# 2024-10-28 10:28:40,210 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 7
# 2024-10-28 10:28:40,212 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 8
# 2024-10-28 10:28:40,214 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 9
# 2024-10-28 10:28:40,216 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib:
# Wrote the following numbers of objects:
# b'bottle': 380
# b'ladle': 193
# b'tableware': 397
# b'wok': 231
#
# 2024-10-28 10:28:40,216 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 0
# 2024-10-28 10:28:40,232 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 1
# 2024-10-28 10:28:40,248 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 2
# 2024-10-28 10:28:40,264 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 3
# 2024-10-28 10:28:40,280 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 4
# 2024-10-28 10:28:40,297 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 5
# 2024-10-28 10:28:40,312 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 6
# 2024-10-28 10:28:40,328 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 7
# 2024-10-28 10:28:40,345 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 8
# 2024-10-28 10:28:40,360 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 9
# 2024-10-28 10:28:40,376 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib:
# Wrote the following numbers of objects:
# b'ladle': 1857
# b'wok': 2032
# b'bottle': 3413
# b'tableware': 3847
#
# 2024-10-28 10:28:40,376 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Cumulative object statistics
# 2024-10-28 10:28:40,376 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib:
# Wrote the following numbers of objects:
# b'bottle': 3793
# b'ladle': 2050
# b'tableware': 4244
# b'wok': 2263
#
# 2024-10-28 10:28:40,376 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Class map.
# Label in GT: Label in tfrecords file
# b'bottle': b'bottle'
# b'ladle': b'ladle'
# b'tableware': b'tableware'
# b'wok': b'wok'
# For the dataset_config in the experiment_spec, please use labels in the tfrecords file, while writing the classmap.
#
# 2024-10-28 10:28:40,376 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Tfrecords generation complete.
# Execution status: PASS

# %%
print("Converting Tfrecords for kitti trainval dataset")
# !mkdir -p $LOCAL_DATA_DIR/tfrecords/july/distractors_palletjack_warehouse && rm -rf $LOCAL_DATA_DIR/tfrecords/july/distractors_palletjack_warehouse/*
# !mkdir -p $LOCAL_PROJECT_DIR/local/training/tao/tfrecords/no_distractors && rm -rf $LOCAL_PROJECT_DIR/local/training/tao/tfrecords/no_distractors/*

# !docker run -it --rm --gpus all -v $LOCAL_PROJECT_DIR:/workspace/tao-experiments $DOCKER_CONTAINER \
                   detectnet_v2 dataset_convert \
                  -d /workspace/tao-experiments/local/training/tao/specs/tfrecords/no_distractors.txt \
                  -o /workspace/tao-experiments/local/training/tao/tfrecords/no_distractors/
# Out:
# Converting Tfrecords for kitti trainval dataset
#
# ==============================
# === TAO Toolkit TensorFlow ===
# ==============================
#
# NVIDIA Release 4.0.0-TensorFlow (build )
# TAO Toolkit Version 4.0.0
#
# Various files include modifications (c) NVIDIA CORPORATION & AFFILIATES.  All rights reserved.
#
# This container image and its contents are governed by the TAO Toolkit End User License Agreement.
# By pulling and using the container, you accept the terms and conditions of this license:
# https://developer.nvidia.com/tao-toolkit-software-license-agreement
#
# NOTE: The SHMEM allocation limit is set to the default of 64MB.  This may be
#    insufficient for TAO Toolkit.  NVIDIA recommends the use of the following flags:
#    docker run --gpus all --ipc=host --ulimit memlock=-1 --ulimit stack=67108864 ...
#
# Using TensorFlow backend.
# 2024-10-28 10:28:44.389921: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Using TensorFlow backend.
# 2024-10-28 10:28:47,997 [INFO] iva.detectnet_v2.dataio.build_converter: Instantiating a kitti converter
# 2024-10-28 10:28:47,998 [INFO] iva.detectnet_v2.dataio.kitti_converter_lib: Num images in
# Train: 360	Val: 40
# 2024-10-28 10:28:47,998 [INFO] iva.detectnet_v2.dataio.kitti_converter_lib: Validation data in partition 0. Hence, while choosing the validationset during training choose validation_fold 0.
# 2024-10-28 10:28:47,998 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 0
# 2024-10-28 10:28:48,001 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 1
# 2024-10-28 10:28:48,002 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 2
# 2024-10-28 10:28:48,004 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 3
# 2024-10-28 10:28:48,005 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 4
# 2024-10-28 10:28:48,006 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 5
# 2024-10-28 10:28:48,007 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 6
# 2024-10-28 10:28:48,008 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 7
# 2024-10-28 10:28:48,009 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 8
# 2024-10-28 10:28:48,010 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 0, shard 9
# 2024-10-28 10:28:48,011 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib:
# Wrote the following numbers of objects:
# b'bottle': 207
# b'wok': 128
# b'tableware': 268
# b'ladle': 132
#
# 2024-10-28 10:28:48,011 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 0
# 2024-10-28 10:28:48,020 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 1
# 2024-10-28 10:28:48,029 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 2
# 2024-10-28 10:28:48,038 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 3
# 2024-10-28 10:28:48,047 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 4
# 2024-10-28 10:28:48,056 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 5
# 2024-10-28 10:28:48,065 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 6
# 2024-10-28 10:28:48,074 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 7
# 2024-10-28 10:28:48,083 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 8
# 2024-10-28 10:28:48,092 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Writing partition 1, shard 9
# 2024-10-28 10:28:48,101 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib:
# Wrote the following numbers of objects:
# b'wok': 1205
# b'bottle': 2129
# b'tableware': 2353
# b'ladle': 1119
#
# 2024-10-28 10:28:48,101 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Cumulative object statistics
# 2024-10-28 10:28:48,101 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib:
# Wrote the following numbers of objects:
# b'bottle': 2336
# b'wok': 1333
# b'tableware': 2621
# b'ladle': 1251
#
# 2024-10-28 10:28:48,101 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Class map.
# Label in GT: Label in tfrecords file
# b'bottle': b'bottle'
# b'wok': b'wok'
# b'tableware': b'tableware'
# b'ladle': b'ladle'
# For the dataset_config in the experiment_spec, please use labels in the tfrecords file, while writing the classmap.
#
# 2024-10-28 10:28:48,101 [INFO] iva.detectnet_v2.dataio.dataset_converter_lib: Tfrecords generation complete.
# Execution status: PASS

# %% [markdown]
# ## 4. Provide Training Specification File <a class="anchor" id="head-4"></a>
#
# * The spec file for training with TAO is provided under `$LOCAL_PROJECT_DIR/specs/training/resnet18_distractors.txt`
# * The tfrecords and the synthetic data generated in the previous steps are provided under the `dataset_config` parameter of the file
# * Other parameters like `augmentation_config`, `model_config`, `postprocessing_config` can be adjusted. Refer to [this](https://docs.nvidia.com/tao/tao-toolkit/text/object_detection/detectnet_v2.html) for a detailed guideline on adjusting the parameters in the spec file
# * For training our model to detect `kitchenware` this `spec` file provided can be used directly

# %%
# !cat $LOCAL_PROJECT_DIR/local/training/tao/specs/training/resnet18_distractors.txt
# Out:
# random_seed: 42
# dataset_config {
#   data_sources {
#     tfrecords_path: "/workspace/tao-experiments/local/training/tao/tfrecords/distractors_kitchen/*"
#     image_directory_path: "/workspace/tao-experiments/kitchenware_sdg/kitchenware_data/distractors_kitchen/Camera"
#   }
#
#   data_sources {
#     tfrecords_path: "/workspace/tao-experiments/local/training/tao/tfrecords/distractors_additional/*"
#     image_directory_path: "/workspace/tao-experiments/kitchenware_sdg/kitchenware_data/distractors_additional/Camera"
#   }
#
#   data_sources {
#     tfrecords_path: "/workspace/tao-experiments/local/training/tao/tfrecords/no_distractors/*"
#     image_directory_path: "/workspace/tao-experiments/kitchenware_sdg/kitchenware_data/no_distractors/Camera"
#   }
#
#   image_extension: "png"
#
#   target_class_mapping {
#     key: "bottle"
#     value: "bottle"
#   }
#
#   target_class_mapping {
#     key: "ladle"
#     value: "ladle"
#   }
#
#   target_class_mapping {
#     key: "wok"
#     value: "wok"
#   }
#
#   target_class_mapping {
#     key: "tableware"
#     value: "tableware"
#   }
#
#  validation_fold: 0
#
# }
#
# augmentation_config {
#   preprocessing {
#     output_image_width: 960
#     output_image_height: 544
#     min_bbox_width: 20.0
#     min_bbox_height: 20.0
#     output_image_channel: 3
#   }
#   spatial_augmentation {
#     hflip_probability: 0.5
#     zoom_min: 0.5
#     zoom_max: 1.5
#     translate_max_x: 8.0
#     translate_max_y: 8.0
#   }
#   color_augmentation {
#     hue_rotation_max: 25.0
#     saturation_shift_max: 0.20000000298
#     contrast_scale_max: 0.10000000149
#     contrast_center: 0.5
#   }
# }
#
# postprocessing_config {
#   target_class_config {
#     key: "bottle"
#     value {
#       clustering_config {
#         clustering_algorithm: DBSCAN
#         dbscan_confidence_threshold: 0.9
#         coverage_threshold: 0.00499999988824
#         dbscan_eps: 0.15000000596
#         dbscan_min_samples: 0.0500000007451
#         minimum_bounding_box_height: 20
#       }
#     }
#   }
#   target_class_config {
#     key: "ladle"
#     value {
#       clustering_config {
#         clustering_algorithm: DBSCAN
#         dbscan_confidence_threshold: 0.9
#         coverage_threshold: 0.00499999988824
#         dbscan_eps: 0.15000000596
#         dbscan_min_samples: 0.0500000007451
#         minimum_bounding_box_height: 20
#       }
#     }
#   }
#   target_class_config {
#     key: "wok"
#     value {
#       clustering_config {
#         clustering_algorithm: DBSCAN
#         dbscan_confidence_threshold: 0.9
#         coverage_threshold: 0.00499999988824
#         dbscan_eps: 0.15000000596
#         dbscan_min_samples: 0.0500000007451
#         minimum_bounding_box_height: 20
#       }
#     }
#   }
#   target_class_config {
#     key: "tableware"
#     value {
#       clustering_config {
#         clustering_algorithm: DBSCAN
#         dbscan_confidence_threshold: 0.9
#         coverage_threshold: 0.00499999988824
#         dbscan_eps: 0.15000000596
#         dbscan_min_samples: 0.0500000007451
#         minimum_bounding_box_height: 20
#       }
#     }
#   }
# }
#
# model_config {
#   pretrained_model_file: "/workspace/tao-experiments/local/training/tao/pretrained_model/resnet18.hdf5"
#   num_layers: 18
#   use_batch_norm: true
#   objective_set {
#     bbox {
#       scale: 35.0
#       offset: 0.5
#     }
#     cov {
#     }
#   }
#   arch: "resnet"
# }
#
# evaluation_config {
#   validation_period_during_training: 10
#   first_validation_epoch: 5
#   minimum_detection_ground_truth_overlap {
#     key: "bottle"
#     value: 0.5
#   }
#   minimum_detection_ground_truth_overlap {
#     key: "ladle"
#     value: 0.5
#   }
#   minimum_detection_ground_truth_overlap {
#     key: "wok"
#     value: 0.5
#   }
#   minimum_detection_ground_truth_overlap {
#     key: "tableware"
#     value: 0.5
#   }
#   evaluation_box_config {
#     key: "bottle"
#     value {
#       minimum_height: 25
#       maximum_height: 9999
#       minimum_width: 25
#       maximum_width: 9999
#     }
#   }
#   evaluation_box_config {
#     key: "ladle"
#     value {
#       minimum_height: 25
#       maximum_height: 9999
#       minimum_width: 25
#       maximum_width: 9999
#     }
#   }
#   evaluation_box_config {
#     key: "wok"
#     value {
#       minimum_height: 25
#       maximum_height: 9999
#       minimum_width: 25
#       maximum_width: 9999
#     }
#   }
#   evaluation_box_config {
#     key: "tableware"
#     value {
#       minimum_height: 25
#       maximum_height: 9999
#       minimum_width: 25
#       maximum_width: 9999
#     }
#   }
#   average_precision_mode: INTEGRATE
# }
#
# cost_function_config {
#   target_classes {
#     name: "bottle"
#     class_weight: 1.0
#     coverage_foreground_weight: 0.0500000007451
#     objectives {
#       name: "cov"
#       initial_weight: 1.0
#       weight_target: 1.0
#     }
#     objectives {
#       name: "bbox"
#       initial_weight: 10.0
#       weight_target: 1.0
#     }
#   }
#   target_classes {
#     name: "ladle"
#     class_weight: 1.0
#     coverage_foreground_weight: 0.0500000007451
#     objectives {
#       name: "cov"
#       initial_weight: 1.0
#       weight_target: 1.0
#     }
#     objectives {
#       name: "bbox"
#       initial_weight: 10.0
#       weight_target: 1.0
#     }
#   }
#   target_classes {
#     name: "wok"
#     class_weight: 1.0
#     coverage_foreground_weight: 0.0500000007451
#     objectives {
#       name: "cov"
#       initial_weight: 1.0
#       weight_target: 1.0
#     }
#     objectives {
#       name: "bbox"
#       initial_weight: 10.0
#       weight_target: 1.0
#     }
#   }
#   target_classes {
#     name: "tableware"
#     class_weight: 1.0
#     coverage_foreground_weight: 0.0500000007451
#     objectives {
#       name: "cov"
#       initial_weight: 1.0
#       weight_target: 1.0
#     }
#     objectives {
#       name: "bbox"
#       initial_weight: 10.0
#       weight_target: 1.0
#     }
#   }
#   enable_autoweighting: true
#   max_objective_weight: 0.999899983406
#   min_objective_weight: 9.99999974738e-05
# }
#
# training_config {
#   batch_size_per_gpu: 32
#   num_epochs: 100
#   learning_rate {
#     soft_start_annealing_schedule {
#       min_learning_rate: 5e-06
#       max_learning_rate: 5e-04
#       soft_start: 0.10000000149
#       annealing: 0.699999988079
#     }
#   }
#   regularizer {
#     type: L1
#     weight: 3.00000002618e-09
#   }
#   optimizer {
#     adam {
#       epsilon: 9.99999993923e-09
#       beta1: 0.899999976158
#       beta2: 0.999000012875
#     }
#   }
#   cost_scaling {
#     initial_exponent: 20.0
#     increment: 0.005
#     decrement: 1.0
#   }
#   visualizer{
#     enabled: true
#     num_images: 10
#     scalar_logging_frequency: 10
#     infrequent_logging_frequency: 5
#     target_class_config {
#       key: "bottle"
#       value: {
#         coverage_threshold: 0.005
#       }
#     }
#     target_class_config {
#       key: "ladle"
#       value: {
#         coverage_threshold: 0.005
#       }
#     }
#     target_class_config {
#       key: "wok"
#       value: {
#         coverage_threshold: 0.005
#       }
#     }
#     target_class_config {
#       key: "tableware"
#       value: {
#         coverage_threshold: 0.005
#       }
#     }
#   }
#   checkpoint_interval: 10
# }
#
# bbox_rasterizer_config {
#   target_class_config {
#     key: "bottle"
#     value {
#       cov_center_x: 0.5
#       cov_center_y: 0.5
#       cov_radius_x: 1.0
#       cov_radius_y: 1.0
#       bbox_min_radius: 1.0
#     }
#   }
#   target_class_config {
#     key: "ladle"
#     value {
#       cov_center_x: 0.5
#       cov_center_y: 0.5
#       cov_radius_x: 1.0
#       cov_radius_y: 1.0
#       bbox_min_radius: 1.0
#     }
#   }
#   target_class_config {
#     key: "wok"
#     value {
#       cov_center_x: 0.5
#       cov_center_y: 0.5
#       cov_radius_x: 1.0
#       cov_radius_y: 1.0
#       bbox_min_radius: 1.0
#     }
#   }
#   target_class_config {
#     key: "tableware"
#     value {
#       cov_center_x: 0.5
#       cov_center_y: 0.5
#       cov_radius_x: 1.0
#       cov_radius_y: 1.0
#       bbox_min_radius: 1.0
#     }
#   }
#   deadzone_radius: 0.400000154972
# }

# %% [markdown]
# ### Hyperparameters can be set in the `spec` file. Adjust batch size parameter depending on the VRAM of your GPU
#
# * You can increase the number of epochs, the number of false positives in real world images keeps decreasing (mAP does not change much after ~250 epochs and usually results in the best trained model for the given dataset)

# %% [markdown]
# ## 5. Run TAO Training <a class="anchor" id="head-5"></a>
#
# * The `$LOCAL_PROJECT_DIR` will be mounted to the TAO docker for training, this contains all the data, pretrained model and spec files (training and inference) needed
#
# #### Ensure that no `_warning.json` file exists in the `$LOCAL_PROJECT_DIR/cloud/training/tao/tfrecords` sub-folders (`distractors_additional`, `ditractors_warehouse` and `no_distractors`)
# * Delete the `_warning.json` files before beginning training
# * TAO training won't begin if the structure of the `tfrecords` folder directories is not as expected

# %%
# Setting up env variables for cleaner command line commands.
# %env KEY=tlt_encode
# %env NUM_GPUS=1
# Out:
# env: KEY=tlt_encode
# env: NUM_GPUS=1

# %% [markdown]
# * TAO Training can be stopped and resumed (`checkpoint_interval` parameter specified in the `spec` file)
# * Tensorboard visualization can be used with TAO [instructions](https://docs.nvidia.com/tao/tao-toolkit/text/tensorboard_visualization.html#visualizing-using-tensorboard).
# * The `$RESULTS_DIR` parameter is the folder where the `$LOCAL_PROJECT_DIR/local/training/tao/detectnet_v2/resnet18_kitchenware` folder which is specified with the `-i` flag in the command below

# %%
# !docker run -it --rm --gpus all -v $LOCAL_PROJECT_DIR:/workspace/tao-experiments $DOCKER_CONTAINER \
            detectnet_v2 train -e /workspace/tao-experiments/local/training/tao/specs/training/resnet18_distractors.txt \
            -r /workspace/tao-experiments/local/training/tao/detectnet_v2/resnet18_kitchenware -k $KEY --gpus $NUM_GPUS
# Out:
# ==============================
# === TAO Toolkit TensorFlow ===
# ==============================
#
# NVIDIA Release 4.0.0-TensorFlow (build )
# TAO Toolkit Version 4.0.0
#
# Various files include modifications (c) NVIDIA CORPORATION & AFFILIATES.  All rights reserved.
#
# This container image and its contents are governed by the TAO Toolkit End User License Agreement.
# By pulling and using the container, you accept the terms and conditions of this license:
# https://developer.nvidia.com/tao-toolkit-software-license-agreement
#
# NOTE: The SHMEM allocation limit is set to the default of 64MB.  This may be
#    insufficient for TAO Toolkit.  NVIDIA recommends the use of the following flags:
#    docker run --gpus all --ipc=host --ulimit memlock=-1 --ulimit stack=67108864 ...
#
# Using TensorFlow backend.
# 2024-10-28 10:44:18.320754: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Using TensorFlow backend.
# 2024-10-28 10:44:22,637 [INFO] iva.common.logging.logging: Log file already exists at /workspace/tao-experiments/local/training/tao/detectnet_v2/resnet18_kitchenware/status.json
# 2024-10-28 10:44:22,637 [INFO] root: Starting DetectNet_v2 Training job
# 2024-10-28 10:44:22,637 [INFO] __main__: Loading experiment spec at /workspace/tao-experiments/local/training/tao/specs/training/resnet18_distractors.txt.
# 2024-10-28 10:44:22,638 [INFO] iva.detectnet_v2.spec_handler.spec_loader: Merging specification from /workspace/tao-experiments/local/training/tao/specs/training/resnet18_distractors.txt
# 2024-10-28 10:44:22,641 [INFO] root: Training gridbox model.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:153: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# 2024-10-28 10:44:22,642 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:153: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# 2024-10-28 10:44:22,866 [INFO] root: Sampling mode of the dataloader was set to user_defined.
# 2024-10-28 10:44:22,909 [INFO] root: Building DetectNet V2 model
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# 2024-10-28 10:44:22,910 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# 2024-10-28 10:44:22,910 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# 2024-10-28 10:44:22,920 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/third_party/keras/tensorflow_backend.py:187: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# 2024-10-28 10:44:23,458 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/third_party/keras/tensorflow_backend.py:187: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# 2024-10-28 10:44:23,554 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# 2024-10-28 10:44:23,554 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# 2024-10-28 10:44:23,554 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 2024-10-28 10:44:23,816 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 2024-10-28 10:44:28,721 [INFO] iva.detectnet_v2.objectives.bbox_objective: Default L1 loss function will be used.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 3, 544, 960)  0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 64, 272, 480) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 64, 272, 480) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 272, 480) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_1 (Conv2D)        (None, 64, 136, 240) 36928       activation_1[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_1 (BatchNormalizati (None, 64, 136, 240) 256         block_1a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_1a_relu_1 (Activation)    (None, 64, 136, 240) 0           block_1a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_2 (Conv2D)        (None, 64, 136, 240) 36928       block_1a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_shortcut (Conv2D) (None, 64, 136, 240) 4160        activation_1[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_2 (BatchNormalizati (None, 64, 136, 240) 256         block_1a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_shortcut (BatchNorm (None, 64, 136, 240) 256         block_1a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 136, 240) 0           block_1a_bn_2[0][0]
#                                                                  block_1a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_1a_relu (Activation)      (None, 64, 136, 240) 0           add_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_1 (Conv2D)        (None, 64, 136, 240) 36928       block_1a_relu[0][0]
# __________________________________________________________________________________________________
# block_1b_bn_1 (BatchNormalizati (None, 64, 136, 240) 256         block_1b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_1b_relu_1 (Activation)    (None, 64, 136, 240) 0           block_1b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_1b_conv_2 (Conv2D)        (None, 64, 136, 240) 36928       block_1b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_1b_bn_2 (BatchNormalizati (None, 64, 136, 240) 256         block_1b_conv_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 136, 240) 0           block_1b_bn_2[0][0]
#                                                                  block_1a_relu[0][0]
# __________________________________________________________________________________________________
# block_1b_relu (Activation)      (None, 64, 136, 240) 0           add_2[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_1 (Conv2D)        (None, 128, 68, 120) 73856       block_1b_relu[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_1 (BatchNormalizati (None, 128, 68, 120) 512         block_2a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_2a_relu_1 (Activation)    (None, 128, 68, 120) 0           block_2a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_2 (Conv2D)        (None, 128, 68, 120) 147584      block_2a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_shortcut (Conv2D) (None, 128, 68, 120) 8320        block_1b_relu[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_2 (BatchNormalizati (None, 128, 68, 120) 512         block_2a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_shortcut (BatchNorm (None, 128, 68, 120) 512         block_2a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 128, 68, 120) 0           block_2a_bn_2[0][0]
#                                                                  block_2a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_2a_relu (Activation)      (None, 128, 68, 120) 0           add_3[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_1 (Conv2D)        (None, 128, 68, 120) 147584      block_2a_relu[0][0]
# __________________________________________________________________________________________________
# block_2b_bn_1 (BatchNormalizati (None, 128, 68, 120) 512         block_2b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_2b_relu_1 (Activation)    (None, 128, 68, 120) 0           block_2b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_2b_conv_2 (Conv2D)        (None, 128, 68, 120) 147584      block_2b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_2b_bn_2 (BatchNormalizati (None, 128, 68, 120) 512         block_2b_conv_2[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 128, 68, 120) 0           block_2b_bn_2[0][0]
#                                                                  block_2a_relu[0][0]
# __________________________________________________________________________________________________
# block_2b_relu (Activation)      (None, 128, 68, 120) 0           add_4[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_1 (Conv2D)        (None, 256, 34, 60)  295168      block_2b_relu[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_1 (BatchNormalizati (None, 256, 34, 60)  1024        block_3a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3a_relu_1 (Activation)    (None, 256, 34, 60)  0           block_3a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_2 (Conv2D)        (None, 256, 34, 60)  590080      block_3a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_shortcut (Conv2D) (None, 256, 34, 60)  33024       block_2b_relu[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_2 (BatchNormalizati (None, 256, 34, 60)  1024        block_3a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_shortcut (BatchNorm (None, 256, 34, 60)  1024        block_3a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 256, 34, 60)  0           block_3a_bn_2[0][0]
#                                                                  block_3a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_3a_relu (Activation)      (None, 256, 34, 60)  0           add_5[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_1 (Conv2D)        (None, 256, 34, 60)  590080      block_3a_relu[0][0]
# __________________________________________________________________________________________________
# block_3b_bn_1 (BatchNormalizati (None, 256, 34, 60)  1024        block_3b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3b_relu_1 (Activation)    (None, 256, 34, 60)  0           block_3b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_3b_conv_2 (Conv2D)        (None, 256, 34, 60)  590080      block_3b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3b_bn_2 (BatchNormalizati (None, 256, 34, 60)  1024        block_3b_conv_2[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 256, 34, 60)  0           block_3b_bn_2[0][0]
#                                                                  block_3a_relu[0][0]
# __________________________________________________________________________________________________
# block_3b_relu (Activation)      (None, 256, 34, 60)  0           add_6[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_1 (Conv2D)        (None, 512, 34, 60)  1180160     block_3b_relu[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_1 (BatchNormalizati (None, 512, 34, 60)  2048        block_4a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_4a_relu_1 (Activation)    (None, 512, 34, 60)  0           block_4a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_2 (Conv2D)        (None, 512, 34, 60)  2359808     block_4a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_shortcut (Conv2D) (None, 512, 34, 60)  131584      block_3b_relu[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_2 (BatchNormalizati (None, 512, 34, 60)  2048        block_4a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_shortcut (BatchNorm (None, 512, 34, 60)  2048        block_4a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 512, 34, 60)  0           block_4a_bn_2[0][0]
#                                                                  block_4a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_4a_relu (Activation)      (None, 512, 34, 60)  0           add_7[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_1 (Conv2D)        (None, 512, 34, 60)  2359808     block_4a_relu[0][0]
# __________________________________________________________________________________________________
# block_4b_bn_1 (BatchNormalizati (None, 512, 34, 60)  2048        block_4b_conv_1[0][0]
# __________________________________________________________________________________________________
# block_4b_relu_1 (Activation)    (None, 512, 34, 60)  0           block_4b_bn_1[0][0]
# __________________________________________________________________________________________________
# block_4b_conv_2 (Conv2D)        (None, 512, 34, 60)  2359808     block_4b_relu_1[0][0]
# __________________________________________________________________________________________________
# block_4b_bn_2 (BatchNormalizati (None, 512, 34, 60)  2048        block_4b_conv_2[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 512, 34, 60)  0           block_4b_bn_2[0][0]
#                                                                  block_4a_relu[0][0]
# __________________________________________________________________________________________________
# block_4b_relu (Activation)      (None, 512, 34, 60)  0           add_8[0][0]
# __________________________________________________________________________________________________
# output_bbox (Conv2D)            (None, 16, 34, 60)   8208        block_4b_relu[0][0]
# __________________________________________________________________________________________________
# output_cov (Conv2D)             (None, 4, 34, 60)    2052        block_4b_relu[0][0]
# ==================================================================================================
# Total params: 11,205,588
# Trainable params: 11,195,860
# Non-trainable params: 9,728
# __________________________________________________________________________________________________
# 2024-10-28 10:44:28,737 [INFO] root: DetectNet V2 model built.
# 2024-10-28 10:44:28,737 [INFO] root: Building rasterizer.
# 2024-10-28 10:44:28,738 [INFO] root: Rasterizers built.
# 2024-10-28 10:44:28,746 [INFO] root: Building training graph.
# 2024-10-28 10:44:28,747 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: Serial augmentation enabled = False
# 2024-10-28 10:44:28,747 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: Pseudo sharding enabled = False
# 2024-10-28 10:44:28,747 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: Max Image Dimensions (all sources): [0, 0]
# 2024-10-28 10:44:28,747 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: number of cpus: 20, io threads: 40, compute threads: 20, buffered batches: 4
# 2024-10-28 10:44:28,747 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: total dataset size 1440, number of sources: 3, batch size per gpu: 32, steps: 45
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# 2024-10-28 10:44:28,771 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/autograph/converters/directives.py:119: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING:tensorflow:Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x762528cbe208>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x762528cbe208>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2024-10-28 10:44:28,793 [WARNING] tensorflow: Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x762528cbe208>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x762528cbe208>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2024-10-28 10:44:28,802 [INFO] iva.detectnet_v2.dataloader.default_dataloader: Bounding box coordinates were detected in the input specification! Bboxes will be automatically converted to polygon coordinates.
# 2024-10-28 10:44:28,926 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: shuffle: True - shard 0 of 1
# WARNING:tensorflow:Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x762528cbe278>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x762528cbe278>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2024-10-28 10:44:28,937 [WARNING] tensorflow: Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x762528cbe278>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x762528cbe278>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2024-10-28 10:44:28,946 [INFO] iva.detectnet_v2.dataloader.default_dataloader: Bounding box coordinates were detected in the input specification! Bboxes will be automatically converted to polygon coordinates.
# 2024-10-28 10:44:29,057 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: shuffle: True - shard 0 of 1
# WARNING:tensorflow:Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x762528cbe2b0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x762528cbe2b0>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2024-10-28 10:44:29,067 [WARNING] tensorflow: Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x762528cbe2b0>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x762528cbe2b0>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2024-10-28 10:44:29,076 [INFO] iva.detectnet_v2.dataloader.default_dataloader: Bounding box coordinates were detected in the input specification! Bboxes will be automatically converted to polygon coordinates.
# 2024-10-28 10:44:29,188 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: shuffle: True - shard 0 of 1
# 2024-10-28 10:44:29,190 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: sampling 3 datasets with weights:
# 2024-10-28 10:44:29,190 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: source: 0 weight: 0.250000
# 2024-10-28 10:44:29,190 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: source: 1 weight: 0.500000
# 2024-10-28 10:44:29,190 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: source: 2 weight: 0.250000
# WARNING:tensorflow:Entity <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7625055b5438>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7625055b5438>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2024-10-28 10:44:29,205 [WARNING] tensorflow: Entity <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7625055b5438>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7625055b5438>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2024-10-28 10:44:29,376 [INFO] __main__: Found 1440 samples in training set
# 2024-10-28 10:44:29,378 [INFO] root: Rasterizing tensors.
# 2024-10-28 10:44:29,489 [INFO] root: Tensors rasterized.
# 2024-10-28 10:44:31,814 [INFO] root: Training graph built.
# 2024-10-28 10:44:31,814 [INFO] root: Building validation graph.
# 2024-10-28 10:44:31,814 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: Serial augmentation enabled = False
# 2024-10-28 10:44:31,814 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: Pseudo sharding enabled = False
# 2024-10-28 10:44:31,814 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: Max Image Dimensions (all sources): [0, 0]
# 2024-10-28 10:44:31,814 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: number of cpus: 20, io threads: 40, compute threads: 20, buffered batches: 4
# 2024-10-28 10:44:31,815 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: total dataset size 160, number of sources: 3, batch size per gpu: 32, steps: 5
# WARNING:tensorflow:Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x762528ca2860>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x762528ca2860>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2024-10-28 10:44:31,822 [WARNING] tensorflow: Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x762528ca2860>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x762528ca2860>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2024-10-28 10:44:31,835 [INFO] iva.detectnet_v2.dataloader.default_dataloader: Bounding box coordinates were detected in the input specification! Bboxes will be automatically converted to polygon coordinates.
# 2024-10-28 10:44:31,951 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: shuffle: False - shard 0 of 1
# WARNING:tensorflow:Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x762528cbe358>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x762528cbe358>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2024-10-28 10:44:31,960 [WARNING] tensorflow: Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x762528cbe358>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x762528cbe358>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2024-10-28 10:44:31,968 [INFO] iva.detectnet_v2.dataloader.default_dataloader: Bounding box coordinates were detected in the input specification! Bboxes will be automatically converted to polygon coordinates.
# 2024-10-28 10:44:32,083 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: shuffle: False - shard 0 of 1
# WARNING:tensorflow:Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x762528cbe3c8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x762528cbe3c8>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2024-10-28 10:44:32,093 [WARNING] tensorflow: Entity <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x762528cbe3c8>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method DriveNetTFRecordsParser.__call__ of <iva.detectnet_v2.dataloader.drivenet_dataloader.DriveNetTFRecordsParser object at 0x762528cbe3c8>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2024-10-28 10:44:32,102 [INFO] iva.detectnet_v2.dataloader.default_dataloader: Bounding box coordinates were detected in the input specification! Bboxes will be automatically converted to polygon coordinates.
# 2024-10-28 10:44:32,300 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: shuffle: False - shard 0 of 1
# 2024-10-28 10:44:32,302 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: sampling 3 datasets with weights:
# 2024-10-28 10:44:32,302 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: source: 0 weight: 0.250000
# 2024-10-28 10:44:32,302 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: source: 1 weight: 0.500000
# 2024-10-28 10:44:32,302 [INFO] modulus.blocks.data_loaders.multi_source_loader.data_loader: source: 2 weight: 0.250000
# WARNING:tensorflow:Entity <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7624cf9d3240>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7624cf9d3240>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2024-10-28 10:44:32,314 [WARNING] tensorflow: Entity <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7624cf9d3240>> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: Unable to locate the source code of <bound method Processor.__call__ of <modulus.blocks.data_loaders.multi_source_loader.processors.asset_loader.AssetLoader object at 0x7624cf9d3240>>. Note that functions defined in certain environments, like the interactive Python shell do not expose their source code. If that is the case, you should to define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.do_not_convert. Original error: could not get source code
# 2024-10-28 10:44:32,423 [INFO] __main__: Found 160 samples in validation set
# 2024-10-28 10:44:32,423 [INFO] root: Rasterizing tensors.
# 2024-10-28 10:44:32,528 [INFO] root: Tensors rasterized.
# 2024-10-28 10:44:32,699 [INFO] root: Validation graph built.
# 2024-10-28 10:44:33,734 [INFO] root: Running training loop.
# 2024-10-28 10:44:33,734 [INFO] __main__: Checkpoint interval: 10
# 2024-10-28 10:44:33,734 [INFO] __main__: Scalars logged at every 4 steps
# 2024-10-28 10:44:33,734 [INFO] __main__: Images logged at every 225 steps
# INFO:tensorflow:Create CheckpointSaverHook.
# 2024-10-28 10:44:33,736 [INFO] tensorflow: Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# 2024-10-28 10:44:35,014 [INFO] tensorflow: Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# 2024-10-28 10:44:36,433 [INFO] tensorflow: Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 2024-10-28 10:44:37,345 [INFO] tensorflow: Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for step-0.
# 2024-10-28 10:44:42,448 [INFO] tensorflow: Saving checkpoints for step-0.
# INFO:tensorflow:epoch = 0.0, learning_rate = 4.9999994e-06, loss = 0.102138214, step = 0
# 2024-10-28 10:45:11,985 [INFO] tensorflow: epoch = 0.0, learning_rate = 4.9999994e-06, loss = 0.102138214, step = 0
# 2024-10-28 10:45:11,998 [INFO] root: None
# 2024-10-28 10:45:12,023 [INFO] iva.detectnet_v2.tfhooks.task_progress_monitor_hook: Epoch 0/100: loss: 0.10214 learning rate: 0.00000 Time taken: 0:00:00 ETA: 0:00:00
# 2024-10-28 10:45:12,024 [INFO] modulus.hooks.sample_counter_hook: Train Samples / sec: 2.145
# INFO:tensorflow:global_step/sec: 0.935064
# 2024-10-28 10:45:16,264 [INFO] tensorflow: global_step/sec: 0.935064
# INFO:tensorflow:epoch = 0.15555555555555556, learning_rate = 5.3713215e-06, loss = 0.09884729, step = 7 (5.433 sec)
# 2024-10-28 10:45:17,419 [INFO] tensorflow: epoch = 0.15555555555555556, learning_rate = 5.3713215e-06, loss = 0.09884729, step = 7 (5.433 sec)
# INFO:tensorflow:global_step/sec: 2.61064
# 2024-10-28 10:45:17,796 [INFO] tensorflow: global_step/sec: 2.61064
# INFO:tensorflow:global_step/sec: 2.35793
# 2024-10-28 10:45:19,493 [INFO] tensorflow: global_step/sec: 2.35793
# INFO:tensorflow:global_step/sec: 2.38596
# 2024-10-28 10:45:21,169 [INFO] tensorflow: global_step/sec: 2.38596
# INFO:tensorflow:global_step/sec: 2.4052
# 2024-10-28 10:45:22,832 [INFO] tensorflow: global_step/sec: 2.4052
# INFO:tensorflow:epoch = 0.4666666666666667, learning_rate = 6.198736e-06, loss = 0.08892175, step = 21 (5.837 sec)
# 2024-10-28 10:45:23,256 [INFO] tensorflow: epoch = 0.4666666666666667, learning_rate = 6.198736e-06, loss = 0.08892175, step = 21 (5.837 sec)
# INFO:tensorflow:global_step/sec: 2.34989
# 2024-10-28 10:45:24,534 [INFO] tensorflow: global_step/sec: 2.34989
# 2024-10-28 10:45:24,535 [INFO] modulus.hooks.sample_counter_hook: Train Samples / sec: 29.167
# INFO:tensorflow:global_step/sec: 2.45055
# 2024-10-28 10:45:26,167 [INFO] tensorflow: global_step/sec: 2.45055
# INFO:tensorflow:global_step/sec: 2.30657
# 2024-10-28 10:45:27,901 [INFO] tensorflow: global_step/sec: 2.30657
# INFO:tensorflow:epoch = 0.7555555555555555, learning_rate = 7.0807787e-06, loss = 0.082384706, step = 34 (5.504 sec)
# 2024-10-28 10:45:28,761 [INFO] tensorflow: epoch = 0.7555555555555555, learning_rate = 7.0807787e-06, loss = 0.082384706, step = 34 (5.504 sec)
# INFO:tensorflow:global_step/sec: 2.35611
# 2024-10-28 10:45:29,599 [INFO] tensorflow: global_step/sec: 2.35611
# INFO:tensorflow:global_step/sec: 2.38557
# 2024-10-28 10:45:31,275 [INFO] tensorflow: global_step/sec: 2.38557
# INFO:tensorflow:global_step/sec: 2.41425
# 2024-10-28 10:45:32,932 [INFO] tensorflow: global_step/sec: 2.41425
# 9724fde9b191:139:190 [0] NCCL INFO Bootstrap : Using eth0:172.17.0.2<0>
# 9724fde9b191:139:190 [0] NCCL INFO NET/Plugin: Failed to find ncclNetPlugin_v6 symbol.
# 9724fde9b191:139:190 [0] NCCL INFO NET/Plugin: Loaded net plugin NCCL RDMA Plugin (v5)
# 9724fde9b191:139:190 [0] NCCL INFO NET/Plugin: Failed to find ncclCollNetPlugin_v6 symbol.
# 9724fde9b191:139:190 [0] NCCL INFO NET/Plugin: Loaded coll plugin SHARP (v5)
# 9724fde9b191:139:190 [0] NCCL INFO cudaDriverVersion 12040
# NCCL version 2.15.1+cuda11.8
# 9724fde9b191:139:190 [0] NCCL INFO Plugin Path : /opt/hpcx/nccl_rdma_sharp_plugin/lib/libnccl-net.so
# 9724fde9b191:139:190 [0] NCCL INFO P2P plugin IBext
# 9724fde9b191:139:190 [0] NCCL INFO NET/IB : No device found.
# 9724fde9b191:139:190 [0] NCCL INFO NET/IB : No device found.
# 9724fde9b191:139:190 [0] NCCL INFO NET/Socket : Using [0]eth0:172.17.0.2<0>
# 9724fde9b191:139:190 [0] NCCL INFO Using network Socket
# 9724fde9b191:139:190 [0] NCCL INFO Channel 00/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 01/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 02/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 03/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 04/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 05/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 06/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 07/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 08/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 09/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 10/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 11/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 12/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 13/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 14/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 15/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 16/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 17/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 18/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 19/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 20/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 21/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 22/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 23/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 24/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 25/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 26/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 27/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 28/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 29/32 :    0
# 9724fde9b191:139:190 [0] NCCL INFO Channel 30/32 :    0
# ...
# 2024-10-28 11:24:01,665 [INFO] iva.detectnet_v2.tfhooks.task_progress_monitor_hook: Epoch 95/100: loss: 0.00076 learning rate: 0.00001 Time taken: 0:00:26.318129 ETA: 0:02:11.590647
# INFO:tensorflow:epoch = 95.02222222222223, learning_rate = 1.0735479e-05, loss = 0.00073884794, step = 4276 (6.392 sec)
# 2024-10-28 11:24:02,188 [INFO] tensorflow: epoch = 95.02222222222223, learning_rate = 1.0735479e-05, loss = 0.00073884794, step = 4276 (6.392 sec)
# INFO:tensorflow:global_step/sec: 0.542964
# 2024-10-28 11:24:02,189 [INFO] tensorflow: global_step/sec: 0.542964
# INFO:tensorflow:global_step/sec: 2.01167
# 2024-10-28 11:24:04,177 [INFO] tensorflow: global_step/sec: 2.01167
# INFO:tensorflow:global_step/sec: 1.91859
# 2024-10-28 11:24:06,262 [INFO] tensorflow: global_step/sec: 1.91859
# INFO:tensorflow:epoch = 95.26666666666667, learning_rate = 1.0340113e-05, loss = 0.0007464007, step = 4287 (5.496 sec)
# 2024-10-28 11:24:07,684 [INFO] tensorflow: epoch = 95.26666666666667, learning_rate = 1.0340113e-05, loss = 0.0007464007, step = 4287 (5.496 sec)
# INFO:tensorflow:global_step/sec: 2.05962
# 2024-10-28 11:24:08,204 [INFO] tensorflow: global_step/sec: 2.05962
# INFO:tensorflow:global_step/sec: 2.00924
# INFO:tensorflow:global_step/sec: 1.91457
# 2024-10-28 11:25:48,059 [INFO] tensorflow: global_step/sec: 1.91457
# INFO:tensorflow:epoch = 99.82222222222222, learning_rate = 5.138325e-06, loss = 0.00083841744, step = 4492 (5.464 sec)
# 2024-10-28 11:25:49,936 [INFO] tensorflow: epoch = 99.82222222222222, learning_rate = 5.138325e-06, loss = 0.00083841744, step = 4492 (5.464 sec)
# INFO:tensorflow:global_step/sec: 2.12498
# 2024-10-28 11:25:49,941 [INFO] tensorflow: global_step/sec: 2.12498
# INFO:tensorflow:global_step/sec: 1.94435
# 2024-10-28 11:25:51,998 [INFO] tensorflow: global_step/sec: 1.94435
# INFO:tensorflow:Saving checkpoints for step-4500.
# 2024-10-28 11:25:53,505 [INFO] tensorflow: Saving checkpoints for step-4500.
# WARNING:tensorflow:Ignoring: /tmp/tmp_sa2sx6g; No such file or directory
# 2024-10-28 11:25:53,601 [WARNING] tensorflow: Ignoring: /tmp/tmp_sa2sx6g; No such file or directory
# 2024-10-28 11:25:55,176 [INFO] iva.detectnet_v2.evaluation.evaluation: step 0 / 5, 0.00s/step
# Matching predictions to ground truth, class 1/4.: 100%|█| 1443/1443 [00:00<00:00, 37273.63it/s]
# Matching predictions to ground truth, class 2/4.: 100%|█| 3362/3362 [00:00<00:00, 38304.46it/s]
# Matching predictions to ground truth, class 3/4.: 100%|█| 2474/2474 [00:00<00:00, 38755.65it/s]
# Matching predictions to ground truth, class 4/4.: 100%|█| 1897/1897 [00:00<00:00, 37303.42it/s]
# Epoch 100/100
# =========================
#
# Validation cost: 0.000312
# Mean average_precision (in %): 9.2533
#
# class name      average precision (in %)
# ------------  --------------------------
# bottle                          12.9753
# ladle                            6.92275
# tableware                        4.7286
# wok                             12.3864
#
# Median Inference Time: 0.010752
# 2024-10-28 11:25:58,658 [INFO] root: Evaluation metrics generated.
# 2024-10-28 11:25:58,658 [INFO] modulus.hooks.sample_counter_hook: Train Samples / sec: 45.218
# 2024-10-28 11:25:58,658 [INFO] root: Training loop completed.
# 2024-10-28 11:25:58,658 [INFO] root: Saving trained model.
# 2024-10-28 11:25:58,873 [INFO] root: Model saved.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# 2024-10-28 11:25:58,873 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# 2024-10-28 11:25:58,873 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# 2024-10-28 11:25:58,874 [INFO] modulus.hooks.sample_counter_hook: Train Samples / sec: 45.218
# 2024-10-28 11:25:59,040 [INFO] root: Training op complete.
# 2024-10-28 11:25:59,041 [INFO] root: DetectNet_v2 training job complete.
# Time taken to run __main__:main: 0:41:36.582247.
# 9724fde9b191:139:190 [0] NCCL INFO comm 0x761e90329cb0 rank 0 nranks 1 cudaDev 0 busId 1000 - Destroy COMPLETE
# Execution status: PASS

# %% [markdown]
# ## 6. Evaluate Trained Model <a class="anchor" id="head-6"></a>
#
# * While generating the `tfrecords` part of the total data generated was kept as a validation set (14% of total data)
# * We will run our model evaluation on this data to obtain metrics

# %%
# !docker run -it --rm --gpus all -v $LOCAL_PROJECT_DIR:/workspace/tao-experiments $DOCKER_CONTAINER \
            detectnet_v2 evaluate -e /workspace/tao-experiments/local/training/tao/specs/training/resnet18_distractors.txt \
            -m /workspace/tao-experiments/local/training/tao/detectnet_v2/resnet18_kitchenware/weights/model.tlt \
            -k $KEY --gpus $NUM_GPUS
# Out:
# ==============================
# === TAO Toolkit TensorFlow ===
# ==============================
#
# NVIDIA Release 4.0.0-TensorFlow (build )
# TAO Toolkit Version 4.0.0
#
# Various files include modifications (c) NVIDIA CORPORATION & AFFILIATES.  All rights reserved.
#
# This container image and its contents are governed by the TAO Toolkit End User License Agreement.
# By pulling and using the container, you accept the terms and conditions of this license:
# https://developer.nvidia.com/tao-toolkit-software-license-agreement
#
# NOTE: The SHMEM allocation limit is set to the default of 64MB.  This may be
#    insufficient for TAO Toolkit.  NVIDIA recommends the use of the following flags:
#    docker run --gpus all --ipc=host --ulimit memlock=-1 --ulimit stack=67108864 ...
#
# Using TensorFlow backend.
# 2024-10-29 02:10:42.561616: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Using TensorFlow backend.
# 
graph was finalized.
# INFO:tensorflow:Running local_init_op.
# 2024-10-29 02:10:49,035 [INFO] tensorflow: Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 2024-10-29 02:10:49,513 [INFO] tensorflow: Done running local_init_op.
# 2024-10-29 02:10:50,135 [INFO] iva.detectnet_v2.evaluation.evaluation: step 0 / 5, 0.00s/step
# Matching predictions to ground truth, class 1/4.: 100%|█| 1414/1414 [00:00<00:00, 34931.53it/s]
# Matching predictions to ground truth, class 2/4.: 100%|█| 2953/2953 [00:00<00:00, 37679.62it/s]
# Matching predictions to ground truth, class 3/4.: 100%|█| 2375/2375 [00:00<00:00, 36520.88it/s]
# Matching predictions to ground truth, class 4/4.: 100%|█| 1663/1663 [00:00<00:00, 31681.22it/s]
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# 2024-10-29 02:10:57,412 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# 2024-10-29 02:10:57,413 [WARNING] tensorflow: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
#
# Validation cost: 0.000859
# Mean average_precision (in %): 8.9318
#
# class name      average precision (in %)
# ------------  --------------------------
# bottle                          12.1691
# ladle                            6.67991
# tableware                        4.95904
# wok                             11.919
#
# Median Inference Time: 0.008755
# 2024-10-29 02:10:57,451 [INFO] __main__: Evaluation complete.
# Time taken to run __main__:main: 0:00:11.167988.
# Execution status: PASS

# %% [markdown]
# ## 7. Visualize Model Performance on Real World Data <a class="anchor" id="head-7"></a>
#
# * Lets visualize the model predictions on a few sample real world images next
# * We will use kichenware images in a warehouse from the `LOCO` dataset to understand if the model is capable of performing real world detections
# * Additional images can be placed under the `loco_kitchenware` folder of this project. The input folder is specified with the `-i` flag in the command below

# %%
# !docker run -it --rm --gpus all -v $LOCAL_PROJECT_DIR:/workspace/tao-experiments $DOCKER_CONTAINER \
                            detectnet_v2 inference -e /workspace/tao-experiments/local/training/tao/specs/inference/new_inference_specs.txt \
                            -o /workspace/tao-experiments/local/training/tao/detectnet_v2/resnet18_kitchenware/1200_model_synthetic \
                            -i /workspace/tao-experiments/images/sample_synthetic \
                            -k $KEY
# Out:
# ==============================
# === TAO Toolkit TensorFlow ===
# ==============================
#
# NVIDIA Release 4.0.0-TensorFlow (build )
# TAO Toolkit Version 4.0.0
#
# Various files include modifications (c) NVIDIA CORPORATION & AFFILIATES.  All rights reserved.
#
# This container image and its contents are governed by the TAO Toolkit End User License Agreement.
# By pulling and using the container, you accept the terms and conditions of this license:
# https://developer.nvidia.com/tao-toolkit-software-license-agreement
#
# NOTE: The SHMEM allocation limit is set to the default of 64MB.  This may be
#    insufficient for TAO Toolkit.  NVIDIA recommends the use of the following flags:
#    docker run --gpus all --ipc=host --ulimit memlock=-1 --ulimit stack=67108864 ...
#
# Using TensorFlow backend.
# 2024-10-29 03:51:18.991548: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Using TensorFlow backend.
# WARNING:tensorflow:Deprecation warnings have been disabled. Set TF_ENABLE_DEPRECATION_WARNINGS=1 to re-enable them.
# /usr/local/lib/python3.6/dist-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.5) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# INFO: Merging specification from /workspace/tao-experiments/local/training/tao/specs/inference/new_inference_specs.txt
# INFO: Overlain images will be saved in the output path.
# INFO: Constructing inferencer
# INFO: Loading model from /workspace/tao-experiments/local/training/tao/detectnet_v2/resnet18_kitchenware/weights/model.tlt:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:245: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:245: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING: From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3, 544, 960)       0
# _________________________________________________________________
# model_1 (Model)              [(None, 4, 34, 60), (None 11205588
# =================================================================
# Total params: 11,205,588
# Trainable params: 11,195,860
# Non-trainable params: 9,728
# _________________________________________________________________
# INFO: Initialized model
# INFO: Commencing inference
# 100%|█████████████████████████████████████████████| 1/1 [00:05<00:00,  5.41s/it]
# INFO: Inference complete
# Execution status: PASS

# %%
from IPython.display import Image 

results_dir = os.path.join(os.environ["LOCAL_PROJECT_DIR"], "local/training/tao/detectnet_v2/resnet18_kitchenware/1200_model_synthetic/test_loco/images_annotated")
# pil_img = Image(filename=os.path.join(os.getenv("LOCAL_PROJECT_DIR"), 'detecnet_v2/july_resnet18_trials/new_pellet_distractors_10k/test_loco/images_annotated/1564562568.298206.jpg'))
                           
image_names = ["1564562568.298206.jpg", "1564562628.517229.jpg", "1564562843.0618184.jpg", "593768,3659.jpg", "516447400,977.jpg"] 
                           
images = [Image(filename = os.path.join(results_dir, image_name)) for image_name in image_names]

display(*images)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 8
#       4 # pil_img = Image(filename=os.path.join(os.getenv("LOCAL_PROJECT_DIR"), 'detecnet_v2/july_resnet18_trials/new_pellet_distractors_10k/test_loco/images_annotated/1564562568.298206.jpg'))
#       6 image_names = ["1564562568.298206.jpg", "1564562628.517229.jpg", "1564562843.0618184.jpg", "593768,3659.jpg", "516447400,977.jpg"]
# ----> 8 images = [Image(filename = os.path.join(results_dir, image_name)) for image_name in image_names]
#      10 display(*images)
#
# Cell In[23], line 8, in <listcomp>(.0)
#       4 # pil_img = Image(filename=os.path.join(os.getenv("LOCAL_PROJECT_DIR"), 'detecnet_v2/july_resnet18_trials/new_pellet_distractors_10k/test_loco/images_annotated/1564562568.298206.jpg'))
#       6 image_names = ["1564562568.298206.jpg", "1564562628.517229.jpg", "1564562843.0618184.jpg", "593768,3659.jpg", "516447400,977.jpg"]
# ----> 8 images = [Image(filename = os.path.join(results_dir, image_name)) for image_name in image_names]
#      10 display(*images)
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/display.py:1050, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#    1048 self.unconfined = unconfined
#    1049 self.alt = alt
# -> 1050 super(Image, self).__init__(data=data, url=url, filename=filename,
#    1051         metadata=metadata)
#    1053 if self.width is None and self.metadata.get('width', {}):
#    1054     self.width = metadata['width']
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/display.py:370, in DisplayObject.__init__(self, data, url, filename, metadata)
#     367 elif self.metadata is None:
#     368     self.metadata = {}
# --> 370 self.reload()
#     371 self._check_data()
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/display.py:1085, in Image.reload(self)
#    1083 """Reload the raw data from file or URL."""
#    1084 if self.embed:
# -> 1085     super(Image,self).reload()
#    1086     if self.retina:
#    1087         self._retina_shape()
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/display.py:396, in DisplayObject.reload(self)
#     394 if self.filename is not None:
#     395     encoding = None if "b" in self._read_flags else "utf-8"
# --> 396     with open(self.filename, self._read_flags, encoding=encoding) as f:
#     397         self.data = f.read()
#     398 elif self.url is not None:
#     399     # Deferred import
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/shinfang-ovx/synthetic_data_generation_training_workflow/local/training/tao/detectnet_v2/resnet18_kitchenware/1200_model_synthetic/test_loco/images_annotated/1564562568.298206.jpg'

# %% [markdown]
# ## 8. Next Steps <a class="anchor" id="head-8"></a>
#
# #### Generating Synthetic Data for your use case:
#
# * Make changes in the Domain Randomization under the Synthetic Data Generation script (`kitchenware_sdg/standalone_kitchenware_sdg.py`
# * Add additional objects of interest in the scene (similar to how `kitchenware` are added, you can add `forklifts`, `ladders` etc.) to generate data
# * Use [different](https://docs.nvidia.com/tao/tao-toolkit/text/tao_toolkit_quick_start_guide.html#downloading-the-models) models for training with TAO (for object detection, you can use `YOLO`, `SSD`, `EfficientDet`)
# * Replicator provides Semantic Segmentation, Instance Segmentation, Depth and various other ground truth annotations along with RGB. You can also write your own ground truth annotator (eg: Pose Estimation: Refer to [sample](https://docs.omniverse.nvidia.com/isaacsim/latest/tutorial_replicator_offline_pose_estimation.html). These can be used for training a model of your own framework and choice
# * Exploring the option of using `Synthetic + Real` data for training a network. Can be particularly useful for generating more data around particular corner cases
#
#
# #### Deploying Trained Models:
#
# * After obtaining satisfactory results with the training process, you can further optimize your model for deployment with the help of Pruning and QAT.
# * TAO models can directly be deployed on Jetson with Isaac ROS or Deepstream which ensures your end-to-end pipeline being optimized (data acquisition -> model inference -> results)
